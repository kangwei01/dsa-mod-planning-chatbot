# %% [markdown]
# We first load in the PDF documents and chunk them.

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
import os

pdf_folder = "data"

pdf_docs = []

for filename in os.listdir(pdf_folder):
    if filename.lower().endswith(".pdf"):
        pdf_path = os.path.join(pdf_folder, filename)
        loader = PyPDFLoader(pdf_path)
        docs = loader.load()

        # Optional: tag documents with source info
        for doc in docs:
            doc.metadata["source"] = filename

        pdf_docs.extend(docs)

print(f"Loaded {len(pdf_docs)} pages from {len(os.listdir(pdf_folder))} PDF files.")

# Split documents into smaller chunks
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,   # size per chunk in characters
    chunk_overlap=200, # overlap between consecutive chunks
    length_function=len,
    separators=["\n\n", "\n", ".", " "]
)

pdf_chunks = splitter.split_documents(pdf_docs)
print(f"Total chunks created: {len(pdf_chunks)}")
# Out:
# Loaded 5 pages from 2 PDF files.
# Total chunks created: 12

# %% [markdown]
# Chunk the JSON CHS Requirements.

# %%
import json

json_path = "data/dsa_chs_requirements.json"

with open(json_path, "r", encoding="utf-8") as f:
    module_data = json.load(f)

json_docs = []

chs_curr = module_data['chs_common_curriculum']

common_core = chs_curr['common_core']
integrated = chs_curr['integrated_courses']
interdisciplinary = chs_curr['interdisciplinary_courses']
year1_preallocation = chs_curr['year1_preallocation']

# %% [markdown]
# For common core modules, the format is more complicated. It contains a list of common core pillars with varying depths of subdictionaries.
# - 6 Pillars: Data Literacy, Communities and Engagement, Artificial Intelligence, Design Thinking, Digital Literacy, Writing.
# - All contains 2 keys: 'pillar' and 'course_options' but communities and engagement contains deeper subdictionaries with different categories of C&E modules.
#
# For integrated and interdisciplinary modules, each sub-curriculum is a list where each element is a dictionary with keys 'pillar' and 'course_options'.
#
# For year 1 preallocated modules, it contains a dictionary with 2 keys, each representing the group of students of which the following modules are preallocated for.

# %%
cc_data = common_core[0] # Data Literacy Pillar
cc_ce = common_core[1] # Communities and Engagement Pillar
cc_ai = common_core[2] # Artificial Intelligence Pillar
cc_dt = common_core[3] # Design Thinking Pillar
cc_digi = common_core[4] # Digital Literacy Pillar
cc_writing = common_core[5] # Writing Pillar

cc_ce['course_options'][0]
# Out:
# {'category': 'Project-based Engagement-Learning C&E courses',
#  'subcategories': [{'gen-coded': False,
#    'courses': [{'code': 'BN4102', 'title': 'Gerontechnology in Ageing'},
#     {'code': 'BN4103',
#      'title': 'Assistive Technology for Persons with Disability'},
#     {'code': 'CDE2001',
#      'title': 'Innovation and Design for Communities',
#      'note': 'Only offered to CDE students.'},
#     {'code': 'CLC1101', 'title': 'Engaging and Building Communities'},
#     {'code': 'CLC2204', 'title': 'Community Development with Youth'},
#     {'code': 'CLC3303', 'title': 'Community Leadership'},
#     {'code': 'CLC3304A', 'title': 'City, Culture and Community'},
#     {'code': 'CLC3307', 'title': 'Learning for Social Change'}]},
#   {'gen-coded': True,
#    'courses': [{'code': 'GEN2000',
#      'title': 'Living Culture: Engaging Indian Communities in Singapore'},
#     {'code': 'GEN2001', 'title': 'Theatre and Community Engagement'},
#     {'code': 'GEN2002X',
#      'title': 'Total Defence Project Against Threat to Community',
#      'note': 'Offered in Semester 1.'},
#     {'code': 'GEN2002Y',
#      'title': 'Total Defence Project Against Threat to Community',
#      'note': 'Offered in Semester 2.'},
#     {'code': 'GEN2003',
#      'title': 'Inclusivity and Equality: Domestic Worker Community'},
#     {'code': 'GEN2004',
#      'title': 'Green Communities in Action: Climate, Species, Crisis'},
#     {'code': 'GEN2005',
#      'title': '“Chineseness”: Engaging Singapore Chinese Communities'},
#     {'code': 'GEN2006',
#      'title': 'Communications for Inter-generational Engagement'},
#     {'code': 'GEN2007', 'title': 'Resilience in Restoration'},
#     {'code': 'GEN2008',
#      'title': 'Purposeful and Productive Ageing in the Community'},
#     {'code': 'GEN2009',
#      'title': 'Voices from the Ground: Stories & Community Narratives'}]}]}

# %%
from langchain_core.documents import Document

chs_curr_json = []

for pillars in common_core:
    pillar_name = pillars['pillar']
    if pillar_name == 'Communities and Engagement':
        course_options = pillars['course_options']

        for categories in course_options:
            category_name = categories['category']
            subcategories = categories['subcategories']

            for sub in subcategories:
                if 'gen-coded' in sub:
                    gen_coded = sub.get('gen-coded')
                    module_info = sub['courses']

                    modules_text = []
                    
                    for mod in module_info:
                        modules_text.append(f"{mod['code']} ({mod['title']})")
                    
                    content = (
                        f"Group: CHS Common Core Modules\n"
                        f"Pillar Name: {pillar_name}\n"
                        f"Category: {category_name}\n"
                        f"Gen-Coded: {gen_coded}\n"
                        f"Modules: {', '.join(modules_text)}"
                    )
                
                elif 'semester' in sub:
                    sem = sub.get('semester')
                    module_info = sub['courses']

                    modules_text = []
                    
                    for mod in module_info:
                        modules_text.append(f"{mod['code']} ({mod['title']})")
                    
                    content = (
                        f"Group: CHS Common Core Modules\n"
                        f"Pillar Name: {pillar_name}\n"
                        f"Category: {category_name}\n"
                        f"Semester: {sem}\n"
                        f"Modules: {', '.join(modules_text)}"
                    )

                chs_curr_json.append(
                    Document(
                        page_content=content,
                        metadata = {"group": "CHS Common Core Modules", "pillar": pillar_name, "category": category_name}
                    )
                )
    else:
        course_options = pillars['course_options']

        modules_text = []

        for mod in course_options:
            if 'footnote' in mod:
                modules_text.append(f"{mod['code']} ({mod['footnote']})")
            
            else:
                modules_text.append(mod['code'])

        content = (
            f"Group: CHS Common Core Modules\n"
            f"Pillar: {pillar_name}\n"
            f"Modules: {', '.join(modules_text)}"
        )

        chs_curr_json.append(
                Document(
                    page_content=content,
                    metadata={"group": "CHS Common Core Modules", "pillar": pillar_name}
                )
            )

for pillars in integrated:
    pillar_name = pillars['pillar']
    course_options = pillars['course_options']
    module_codes = [mod['code'] for mod in course_options]

    content = (
            f"Group: CHS Integrated Modules\n"
            f"Pillar: {pillar_name}\n"
            f"Modules: {', '.join(module_codes)}"
        )
    
    chs_curr_json.append(
        Document(page_content=content, metadata = {"group": "CHS Integrated Modules", "pillar": pillar_name})
    )

for pillars in interdisciplinary:
    pillar_name = pillars['pillar']
    course_options = pillars['course_options']
    module_codes = [mod['code'] for mod in course_options]

    content = (
            f"Group: CHS Interdisciplinary Modules\n"
            f"Pillar: {pillar_name}\n"
            f"Modules: {', '.join(module_codes)}"
        )
    
    chs_curr_json.append(
        Document(page_content=content, metadata = {"group": "CHS Interdisciplinary Modules", "pillar": pillar_name})
    )
    
for student_group, preallocation in year1_preallocation.items():
    sem1_modules = preallocation['semester_1']
    sem2_modules = preallocation['semester_2']

    student = "Student ID ending with odd number" if student_group == "student_id_ending_odd" else "Student ID ending with even number"

    content = (
        f"CHS Allocated Student Group: {student}\n"
        f"Semester 1 Modules: {', '.join(sem1_modules)}\n"
        f"Semester 2 Modules {', '.join(sem2_modules)}"
    )

    chs_curr_json.append(
        Document(page_content=content, metadata = {"group": "CHS Year 1 Preallocated Modules"})
    )

# %%
chs_curr_json
# Out:
# [Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Data Literacy'}, page_content='Group: CHS Common Core Modules\nPillar: Data Literacy\nModules: GEA1000, DSA1101, ST1131, DSE1101 (DSE1101 can only be read by students in the Data Science and Economics programme.), BT1101'),
#  Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Communities and Engagement', 'category': 'Project-based Engagement-Learning C&E courses'}, page_content='Group: CHS Common Core Modules\nPillar Name: Communities and Engagement\nCategory: Project-based Engagement-Learning C&E courses\nGen-Coded: False\nModules: BN4102 (Gerontechnology in Ageing), BN4103 (Assistive Technology for Persons with Disability), CDE2001 (Innovation and Design for Communities), CLC1101 (Engaging and Building Communities), CLC2204 (Community Development with Youth), CLC3303 (Community Leadership), CLC3304A (City, Culture and Community), CLC3307 (Learning for Social Change)'),
#  Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Communities and Engagement', 'category': 'Project-based Engagement-Learning C&E courses'}, page_content='Group: CHS Common Core Modules\nPillar Name: Communities and Engagement\nCategory: Project-based Engagement-Learning C&E courses\nGen-Coded: True\nModules: GEN2000 (Living Culture: Engaging Indian Communities in Singapore), GEN2001 (Theatre and Community Engagement), GEN2002X (Total Defence Project Against Threat to Community), GEN2002Y (Total Defence Project Against Threat to Community), GEN2003 (Inclusivity and Equality: Domestic Worker Community), GEN2004 (Green Communities in Action: Climate, Species, Crisis), GEN2005 (“Chineseness”: Engaging Singapore Chinese Communities), GEN2006 (Communications for Inter-generational Engagement), GEN2007 (Resilience in Restoration), GEN2008 (Purposeful and Productive Ageing in the Community), GEN2009 (Voices from the Ground: Stories & Community Narratives)'),
#  Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Communities and Engagement', 'category': 'Service-Learning C&E courses'}, page_content='Group: CHS Common Core Modules\nPillar Name: Communities and Engagement\nCategory: Service-Learning C&E courses\nSemester: 1\nModules: GEN2050X (Teach SG), GEN2060X (Reconnect SeniorsSG), GEN2061X (Support Healthy AgeingSG), GEN2062X (Community Activities for Seniors with SG Cares), GEN2070X (Community Link (Comlink) Befrienders)'),
#  Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Communities and Engagement', 'category': 'Service-Learning C&E courses'}, page_content='Group: CHS Common Core Modules\nPillar Name: Communities and Engagement\nCategory: Service-Learning C&E courses\nSemester: 2\nModules: GEN2050Y (Teach SG), GEN2060Y (Reconnect SeniorsSG), GEN2061Y (Support Healthy AgeingSG), GEN2062Y (Community Activities for Seniors with SG Cares), GEN2070Y (Community Link (Comlink) Befrienders)'),
#  Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Artificial Intelligence'}, page_content='Group: CHS Common Core Modules\nPillar: Artificial Intelligence\nModules: HS1501, HS1502, HS1503, IT1244, CS2109S (#)'),
#  Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Design Thinking'}, page_content='Group: CHS Common Core Modules\nPillar: Design Thinking\nModules: DTK1234'),
#  Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Digital Literacy'}, page_content='Group: CHS Common Core Modules\nPillar: Digital Literacy\nModules: GEI1001, GEI1002, NM2207, CS1010X / CS1101S, COS1000, CM3267, LSM2302 / BZ2001, SP2273 (*), UTC2851, UTC2852'),
#  Document(metadata={'group': 'CHS Common Core Modules', 'pillar': 'Writing'}, page_content="Group: CHS Common Core Modules\nPillar: Writing\nModules: FAS1101, SP1541, SP1541X, SP2271 (Only students reading the MA-CS DDP and/or SoC's Artificial Intelligence minor or second major/minor in Computer Science can use CS2109S to fulfil the Artificial Intelligence requirement.)"),
#  Document(metadata={'group': 'CHS Integrated Modules', 'pillar': 'Humanities'}, page_content='Group: CHS Integrated Modules\nPillar: Humanities\nModules: HSH1000'),
#  Document(metadata={'group': 'CHS Integrated Modules', 'pillar': 'Social Sciences'}, page_content='Group: CHS Integrated Modules\nPillar: Social Sciences\nModules: HSS1000'),
#  Document(metadata={'group': 'CHS Integrated Modules', 'pillar': 'Asian Studies'}, page_content='Group: CHS Integrated Modules\nPillar: Asian Studies\nModules: HSA1000'),
#  Document(metadata={'group': 'CHS Integrated Modules', 'pillar': 'Scientific Inquiry I'}, page_content='Group: CHS Integrated Modules\nPillar: Scientific Inquiry I\nModules: HSI1000, SP2274'),
#  Document(metadata={'group': 'CHS Integrated Modules', 'pillar': 'Scientific Inquiry II'}, page_content='Group: CHS Integrated Modules\nPillar: Scientific Inquiry II\nModules: HSI20XX'),
#  Document(metadata={'group': 'CHS Interdisciplinary Modules', 'pillar': 'Course Choice I'}, page_content='Group: CHS Interdisciplinary Modules\nPillar: Course Choice I\nModules: HS29XX'),
#  Document(metadata={'group': 'CHS Interdisciplinary Modules', 'pillar': 'Course Choice II'}, page_content='Group: CHS Interdisciplinary Modules\nPillar: Course Choice II\nModules: HS29XX'),
#  Document(metadata={'group': 'CHS Year 1 Preallocated Modules'}, page_content='CHS Allocated Student Group: Student ID ending with odd number\nSemester 1 Modules: HSH1000, HSI1000\nSemester 2 Modules HSA1000, HSS1000, DTK1234'),
#  Document(metadata={'group': 'CHS Year 1 Preallocated Modules'}, page_content='CHS Allocated Student Group: Student ID ending with even number\nSemester 1 Modules: HSA1000, HSS1000, DTK1234\nSemester 2 Modules HSH1000, HSI1000')]

# %% [markdown]
# Combine all information.

# %%
all_info = pdf_chunks + chs_curr_json

# %% [markdown]
# Create an embedding store using OllamaEmbeddings and FAISS.

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings

embedding = OllamaEmbeddings(model="mxbai-embed-large")  # or 'nomic-embed-text'
vectorstore = FAISS.from_documents(all_info, embedding)
vectorstore.save_local("curriculum_info_vectors")

# %% [markdown]
# test drive

# %%
from langchain_core.messages import HumanMessage, AIMessage
from langgraph.graph import StateGraph, START, END
from langgraph.graph import START, MessagesState, StateGraph
from langchain_community.chat_models import ChatOllama
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings

embedding = OllamaEmbeddings(model="mxbai-embed-large") 

vectorstore = FAISS.load_local("curriculum_info_vectors", embedding, allow_dangerous_deserialization=True)  # pass the same embedding instance
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 4})

class ModState(MessagesState):
    messages: any = None
    retrieved_docs: any = None


llm = ChatOllama(
    model="qwen3:14b",
    temperature=0.2,
    num_predict=-1,
    reasoning=True,
    validate_model_on_init=True,
)


def retrieve_node(state):
    print("🔹 Running retrieve_node")
    query = state["messages"][-1].content  # last user message
    docs = retriever.invoke(query)
    print(f"Data type of docs: {type(docs)}")
    state["retrieved_docs"] = docs
    state["messages"].append(AIMessage(content=f"Retrieved {len(docs)} document(s)."))
    print(f"Retrieved {len(docs)} document(s).")
    return state


def llm_node(state):
    print("🔹 Running llm_node")
    print(state)
    context = "\n\n".join([d.page_content for d in state["retrieved_docs"]])
    query = state["messages"][0].content

    prompt = f"""You are a university module planning assistant.
    Use the provided context below to answer questions accurately about modules, pillars, or degree requirements.

    Context:
    {context}

    Question:
    {query}
    """

    response = llm.invoke([HumanMessage(content=prompt)])
    print(f"Response: {response}")

    state['messages'].append(AIMessage(content=response.content))
    return state

graph = StateGraph(ModState)

# Add nodes
graph.add_node("retrieve", retrieve_node)
graph.add_node("llm", llm_node)

# 3️⃣ Connect edges (define flow)
graph.add_edge(START, "retrieve")
graph.add_edge("retrieve", "llm")
graph.add_edge("llm", END)

# 4️⃣ Compile graph
app = graph.compile()

# 5️⃣ Test run
state = {
    "messages": [HumanMessage(content="What are the modules in common core communities and engagement pillar?")],
    "retrieved_docs": None
}

result = app.invoke(state)

# 6️⃣ Print results
for msg in result["messages"]:
    print(f"{msg.type.upper()}: {msg.content}")
# Out:
# C:\Users\HopeE\AppData\Local\Temp\ipykernel_16704\3425539744.py:8: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embedding = OllamaEmbeddings(model="mxbai-embed-large")
# C:\Users\HopeE\AppData\Local\Temp\ipykernel_16704\3425539744.py:18: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   llm = ChatOllama(
# 🔹 Running retrieve_node
# Data type of docs: <class 'list'>
# Retrieved 4 document(s).
# 🔹 Running llm_node
# {'messages': [HumanMessage(content='What are the modules in common core communities and engagement pillar?', additional_kwargs={}, response_metadata={}), AIMessage(content='Retrieved 4 document(s).', additional_kwargs={}, response_metadata={})], 'retrieved_docs': [Document(id='1e577e70-b363-41ad-9df6-cf2b913473ee', metadata={'group': 'Common Core Modules', 'pillar': 'Communities and Engagement', 'category': 'Service-Learning C&E courses'}, page_content='Group: Common Core Modules\nPillar Name: Communities and Engagement\nCategory: Service-Learning C&E courses\nGen-Coded:  \nModules: GEN2050Y (Teach SG), GEN2060Y (Reconnect SeniorsSG), GEN2061Y (Support Healthy AgeingSG), GEN2062Y (Community Activities for Seniors with SG Cares), GEN2070Y (Community Link (Comlink) Befrienders)'), Document(id='4cc4ab6b-a9be-4941-88c8-8c105f266324', metadata={'group': 'Common Core Modules', 'pillar': 'Communities and Engagement', 'category': 'Service-Learning C&E courses'}, page_content='Group: Common Core Modules\nPillar Name: Communities and Engagement\nCategory: Service-Learning C&E courses\nGen-Coded:  \nModules: GEN2050X (Teach SG), GEN2060X (Reconnect SeniorsSG), GEN2061X (Support Healthy AgeingSG), GEN2062X (Community Activities for Seniors with SG Cares), GEN2070X (Community Link (Comlink) Befrienders)'), Document(id='fa928afc-d0fa-47bc-9409-e1d99bb90539', metadata={'group': 'Common Core Modules', 'pillar': 'Communities and Engagement', 'category': 'Project-based Engagement-Learning C&E courses'}, page_content='Group: Common Core Modules\nPillar Name: Communities and Engagement\nCategory: Project-based Engagement-Learning C&E courses\nGen-Coded: True\nModules: GEN2000 (Living Culture: Engaging Indian Communities in Singapore), GEN2001 (Theatre and Community Engagement), GEN2002X (Total Defence Project Against Threat to Community), GEN2002Y (Total Defence Project Against Threat to Community), GEN2003 (Inclusivity and Equality: Domestic Worker Community), GEN2004 (Green Communities in Action: Climate, Species, Crisis), GEN2005 (“Chineseness”: Engaging Singapore Chinese Communities), GEN2006 (Communications for Inter-generational Engagement), GEN2007 (Resilience in Restoration), GEN2008 (Purposeful and Productive Ageing in the Community), GEN2009 (Voices from the Ground: Stories & Community Narratives)'), Document(id='881e5f96-a47c-4693-8637-61be0713f7f6', metadata={'group': 'Common Core Modules', 'pillar': 'Communities and Engagement', 'category': 'Project-based Engagement-Learning C&E courses'}, page_content='Group: Common Core Modules\nPillar Name: Communities and Engagement\nCategory: Project-based Engagement-Learning C&E courses\nGen-Coded: False\nModules: BN4102 (Gerontechnology in Ageing), BN4103 (Assistive Technology for Persons with Disability), CDE2001 (Innovation and Design for Communities), CLC1101 (Engaging and Building Communities), CLC2204 (Community Development with Youth), CLC3303 (Community Leadership), CLC3304A (City, Culture and Community), CLC3307 (Learning for Social Change)')]}
# Response: content='The **Common Core Modules** under the **Communities and Engagement** pillar include the following modules, categorized by type:\n\n---\n\n### **1. Service-Learning C&E Courses**  \n**Gen-Coded: Not specified (modules with suffixes "X" and "Y")**  \n- **GEN2050Y**: Teach SG  \n- **GEN2060Y**: Reconnect SeniorsSG  \n- **GEN2061Y**: Support Healthy AgeingSG  \n- **GEN2062Y**: Community Activities for Seniors with SG Cares  \n- **GEN2070Y**: Community Link (Comlink) Befrienders  \n\n- **GEN2050X**: Teach SG  \n- **GEN2060X**: Reconnect SeniorsSG  \n- **GEN2061X**: Support Healthy AgeingSG  \n- **GEN2062X**: Community Activities for Seniors with SG Cares  \n- **GEN2070X**: Community Link (Comlink) Befrienders  \n\n---\n\n### **2. Project-Based Engagement-Learning C&E Courses**  \n#### **Gen-Coded: True**  \n- **GEN2000**: Living Culture: Engaging Indian Communities in Singapore  \n- **GEN2001**: Theatre and Community Engagement  \n- **GEN2002X**: Total Defence Project Against Threat to Community  \n- **GEN2002Y**: Total Defence Project Against Threat to Community  \n- **GEN2003**: Inclusivity and Equality: Domestic Worker Community  \n- **GEN2004**: Green Communities in Action: Climate, Species, Crisis  \n- **GEN2005**: “Chineseness”: Engaging Singapore Chinese Communities  \n- **GEN2006**: Communications for Inter-generational Engagement  \n- **GEN2007**: Resilience in Restoration  \n- **GEN2008**: Purposeful and Productive Ageing in the Community  \n- **GEN2009**: Voices from the Ground: Stories & Community Narratives  \n\n#### **Gen-Coded: False**  \n- **BN4102**: Gerontechnology in Ageing  \n- **BN4103**: Assistive Technology for Persons with Disability  \n- **CDE2001**: Innovation and Design for Communities  \n- **CLC1101**: Engaging and Building Communities  \n- **CLC2204**: Community Development with Youth  \n- **CLC3303**: Community Leadership  \n- **CLC3304A**: City, Culture and Community  \n- **CLC3307**: Learning for Social Change  \n\n---\n\n### Summary  \nThe **Communities and Engagement** pillar includes **Service-Learning** modules (with "X" and "Y" variants) and **Project-Based Engagement-Learning** modules (with and without Gen-Coding). All modules listed above are part of the Common Core requirements.' additional_kwargs={} response_metadata={'model': 'qwen3:14b', 'created_at': '2025-11-03T15:00:22.0919337Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 59686435900, 'load_duration': 7937418000, 'prompt_eval_count': 1491, 'prompt_eval_duration': 863792300, 'eval_count': 620, 'eval_duration': 20818711200} id='lc_run--36628064-ab82-4217-8fd5-94af386e3921-0'
# HUMAN: What are the modules in common core communities and engagement pillar?
# AI: Retrieved 4 document(s).
# AI: The **Common Core Modules** under the **Communities and Engagement** pillar include the following modules, categorized by type:
#
# ---
#
# ### **1. Service-Learning C&E Courses**
# **Gen-Coded: Not specified (modules with suffixes "X" and "Y")**
# - **GEN2050Y**: Teach SG
# - **GEN2060Y**: Reconnect SeniorsSG
# - **GEN2061Y**: Support Healthy AgeingSG
# - **GEN2062Y**: Community Activities for Seniors with SG Cares
# - **GEN2070Y**: Community Link (Comlink) Befrienders
#
# - **GEN2050X**: Teach SG
# - **GEN2060X**: Reconnect SeniorsSG
# - **GEN2061X**: Support Healthy AgeingSG
# - **GEN2062X**: Community Activities for Seniors with SG Cares
# - **GEN2070X**: Community Link (Comlink) Befrienders
#
# ---
#
# ### **2. Project-Based Engagement-Learning C&E Courses**
# #### **Gen-Coded: True**
# - **GEN2000**: Living Culture: Engaging Indian Communities in Singapore
# - **GEN2001**: Theatre and Community Engagement
# - **GEN2002X**: Total Defence Project Against Threat to Community
# - **GEN2002Y**: Total Defence Project Against Threat to Community
# - **GEN2003**: Inclusivity and Equality: Domestic Worker Community
# - **GEN2004**: Green Communities in Action: Climate, Species, Crisis
# - **GEN2005**: “Chineseness”: Engaging Singapore Chinese Communities
# - **GEN2006**: Communications for Inter-generational Engagement
# - **GEN2007**: Resilience in Restoration
# - **GEN2008**: Purposeful and Productive Ageing in the Community
# - **GEN2009**: Voices from the Ground: Stories & Community Narratives
#
# #### **Gen-Coded: False**
# - **BN4102**: Gerontechnology in Ageing
# - **BN4103**: Assistive Technology for Persons with Disability
# - **CDE2001**: Innovation and Design for Communities
# - **CLC1101**: Engaging and Building Communities
# - **CLC2204**: Community Development with Youth
# - **CLC3303**: Community Leadership
# - **CLC3304A**: City, Culture and Community
# - **CLC3307**: Learning for Social Change
#
# ---
#
# ### Summary
# The **Communities and Engagement** pillar includes **Service-Learning** modules (with "X" and "Y" variants) and **Project-Based Engagement-Learning** modules (with and without Gen-Coding). All modules listed above are part of the Common Core requirements.
